# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("extra_data.csv")

# %% [markdown]
# ## Column description
# - `MlsNumber` - property id
# - `LivingArea` - meterage, in variuos units (sad)
# - `YearBuilt` - year built, small amount oh nans
# - `MunicipalTax` - a tax paid to local authorities for a building
# - `SchoolTax` - a tax paid to local school for education
# - `CondoFees` - a levy paid to cover maintenance costs (czynsz) - alot of nans
# - `HeatingEnergy` - type of energy used to heat the house
# - `HeatingSystem` - irrelevant (lot of nans also)
# - `Proximity` - facilities in neighbourhood
# - `SewageSystem` - the type of system used to siphon off sewage
# - `LotAssessment` - building assessment made by auctionists on auction (lot of nans)
# - `BuildingAssessment` - lots of nans
# - `Pool` - type of pool (lots of nans, but it may indicate absence of pool)
# - `View`- type of view, e.g. panoramic, water (lots of nans)
# - `Garage` - type of garage
# - `Parking` - type of parking
# - `Zoning` - zoning
# - `Ąrea`- area of property (hose + facilities, lots of nans)
# - `WaterSupply` - type of water supply
# - `LotDepth`, `Lotfrontage`, `FloorCovering`, `Topography`, `Insurance`,  - drop (lots of nans)
# - `MuniciaplAssessment` - an assessment made by local authorities of building price

# %%
data = data[['MlsNumber', 'LivingArea', 'Proximity']]
data.dropna(inplace = True)

# %% [markdown]
# Dealing with `LivingArea` feature.

# %%
area = data['LivingArea'].str.split(' ', n = 1, expand=True)
area[0] = area[0].str.replace(',', '')
data['AreaNumber'] = area[0].astype(float)
data['AreaUnits'] = area[1]
data.drop('LivingArea', axis = 1, inplace=True)

# %%
# dealing with square feet
data['AreaNumber'] = np.where(data['AreaUnits'].isin(['Square Feet', 'SF']), round(data['AreaNumber'] * 0.09290304, 2), data['AreaNumber'])
data['AreaUnits'] = np.where(data['AreaUnits'].isin(['Square Feet', 'SF']), np.nan, data['AreaUnits'])

# %%
# dealing with meters squared
data['AreaUnits'] = np.where(data['AreaUnits'].isin(['Square metres', 'Square Metres', 'm²', 'MC', 'PC', 'pi²', None]), np.nan, data['AreaUnits'])

# %%
#manually correcting several values
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 39 ft', round(data['AreaNumber'] *3.62321856, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 71.60 ft', round(data['AreaNumber'] *6.651857664, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 16.78 M', round(data['AreaNumber'] *16.78, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 36.50 ft', round(data['AreaNumber'] *3.39096096, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 12.53 M', round(data['AreaNumber'] *12.53, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 47 ft', round(data['AreaNumber'] *4.36644288, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 30 ft', round(data['AreaNumber'] *2.7870912, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 24.30 ft', round(data['AreaNumber'] *2.257543872, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 28 ft', round(data['AreaNumber'] *2.60128512, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 34.80 ft', round(data['AreaNumber'] *3.233025792, 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 10.52 ft', round(data['AreaNumber'], 2), data['AreaNumber'])
data['AreaNumber'] = np.where(data['AreaUnits'] == 'x 27 ft', round(data['AreaNumber'] *2.49124513, 2), data['AreaNumber'])
data.drop('AreaUnits', axis = 1, inplace=True)

# %% [markdown]
# Dealing with `Proximity` feature.

# %%
# version first
max(data['Proximity'].str.split(',').apply(lambda x: len(x)))
proximity = data['Proximity'].str.split(', ', n = 17, expand = True)
proximity.columns = [str(i) for i in range(16)]
iter = 0
for i in range(16):
    col = pd.get_dummies(proximity[str(i)], prefix = str(iter))
    iter += 1
    data = data.join(col)

# %%
data['Proximity'] = data['Proximity'].str.split(', ')

# %%
# version second
proximitySet = list(data['Proximity'])
proximity = list(set().union(*proximitySet))
proximity
# Out:
# ['',
#  'Quartier des spectacles',
#  'Public transportation',
#  'M�tro Monk',
#  'Garderies',
#  'th�atres',
#  'Maisonneuve Park',
#  'rue St-Denis',
#  'Fairview shopping center',
#  'Jardin Botanique',
#  'Groceries',
#  'clinic',
#  'High school',
#  'IGA',
#  'bell centre',
#  'plateau',
#  'gym',
#  'Place Versailles',
#  'Maisonneuve Market',
#  'March� Maisonneuve',
#  "Les Galeries d'Anjou mall",
#  'Aquadome,sports center',
#  'Jardin botanique',
#  'Riviere',
#  'Supermarch�s',
#  'De multiples services',
#  'Old Port of Montral',
#  'grocery store',
#  'Restos-boutiques-Bar ',
#  "Centre d'Achat Forest",
#  'grocery stores',
#  'Cin�ma Beaubien',
#  'Restos-boutiques',
#  'Commercial center',
#  'M�tro Frontenac',
#  'bicycle path',
#  'Access to highway 20',
#  'medical clinic',
#  'Mountain',
#  'acc�s autoroutes',
#  'supermarket',
#  'daycare',
#  'Fairview Mall',
#  'Restaurants et Bistros',
#  'Lachine Canal',
#  'Commerces',
#  'All within walking distance.',
#  'bank',
#  'lac St-Louis',
#  'German school AVH',
#  'Grocery',
#  'Centre sportif CEPSUM',
#  'Autoroute 20,13,720',
#  "Centre d'achat Le Boulevard",
#  'public access to lake',
#  'Mile-ex',
#  'Laurier street',
#  'Tennis',
#  'Boutiques et commerces branch�s',
#  'community centre',
#  'Bonne garderie',
#  'Atwater Market/Lachine Canal',
#  'University',
#  'Victoria Bridge',
#  'Elementary school',
#  'grocery store,b106',
#  'grocery',
#  'Rockland Center',
#  'Westmount Recreation Centre',
#  'pres du future train banlieue AMT',
#  'Public pool',
#  'Claude Robillard Sports Club',
#  'Cafés',
#  'SHOPING CENTER',
#  'Olympic Stadium',
#  'restos-boutiques ',
#  'Boutiques and restaurants',
#  'Future gare de train de banlieue',
#  'Magasin,�picerie',
#  'bombardier',
#  'Metro Grocery Store',
#  '�piceries fines services',
#  'Commuter train',
#  'Bi�dome',
#  'Old Montreal',
#  'Centre ville',
#  'centre-ville..',
#  'Henri-Bourassa Metro',
#  'Atwater market',
#  'Daycare',
#  'garderies',
#  'Place des Arts',
#  'TUNNEL HIPPOLYTE',
#  'bistros..',
#  'Waterside',
#  'Bell Centre',
#  'Montreal Casino',
#  'centre du commerce mondial,',
#  'cinema and shopping center',
#  'Ferry',
#  '�piceries',
#  'ANGRIGNON Metro',
#  'clinique',
#  'Medical clinic',
#  'Honoré-Beaugrand Metro Station',
#  'the best restaurants',
#  'Radisson subway,Place Versailles mall,Loblaw',
#  'Lachine Canal/Atwater Market',
#  'commercial centers',
#  'Parc La Fontaine',
#  'rue Mt-Royal',
#  'Water front',
#  'shopping',
#  'Boutiques',
#  "Galeries et Halles d'Anjou",
#  '+',
#  'Highway 40',
#  'resto',
#  'March� Jean-Talon',
#  'Summer festivals',
#  'Parc Molson',
#  'Pharmacy',
#  'college/cegep',
#  'CHINA TOWN',
#  'banks',
#  "Baie D'Urf� Yacht Club",
#  'Restos-boutique-Place des Arts-M�tro',
#  'Atwater Market and Lachine Canal',
#  'Lachine Canal and Atwater Market',
#  'outremont',
#  'Pont De La 25',
#  'Station Metro Beaudry',
#  'SAQ et restos.',
#  'metro',
#  'Pauline Julien Theatre',
#  'bixi',
#  'Skate rink of Old Port',
#  'shopping mall',
#  'Angrignon Metro',
#  'Two steps from MCGILL and downtown',
#  'Coll�ge Mont St-Louis',
#  'Lake St.Louis',
#  'Centre-Claude Robillard',
#  "Centre commercial Les Galeries d'anjou",
#  'Lac St louis',
#  'gorgeous park along the water',
#  'Services',
#  'Lachine canal',
#  'Park - green area',
#  'jardin botanique',
#  '�cole secondaire',
#  'services et centres commerciaux ',
#  'Monk Blvd (shops)',
#  'Pr�s nouveau train pr�vu d�c.2014',
#  "Ctre d'achats",
#  'Centre sportif',
#  'restos',
#  'international airport',
#  'Vieux-Port',
#  'cin�ma',
#  'Interior access to Les Bains Scandinaves',
#  'Groceries and businesses',
#  'Pharmacie',
#  'library',
#  'cafés',
#  'mall',
#  '�cole primaire',
#  'Monkland',
#  "Gal. d'anjou",
#  'near all services',
#  'March� Maisonneuve ',
#  "YUL Trudeau Int'l Airport",
#  "Magasins,Centre D'achats",
#  'Shops and restaurants',
#  'Boutique Hotels,',
#  'Wellington Plaza',
#  'Kuper Acadany',
#  'Atwater market,lachine canal',
#  'Ste-Catherine',
#  'Garderie',
#  'parcs',
#  'm�tro ',
#  'Snowdon metro.',
#  'Parc LaFontaine',
#  'Promenade Masson',
#  'Mt-Royal',
#  'Epicerie',
#  'm�tro Berri',
#  'pres du futur train banlieue',
#  'gascogne,maxi-jean coutu-banque',
#  'Biblioth�que',
#  'SHOPPING MALL',
#  "Centred'achat-YMCA",
#  'HW 13 & 40',
#  'Metro',
#  'Grand Place',
#  'Curling',
#  'services',
#  'pharmacie',
#  'Easy Access to Highway 40 & 20',
#  'MCGILL U AND CONCORDIA U',
#  'shopping center and cinema',
#  'bars',
#  'Jacques-Cartier bridge',
#  'Hospital',
#  '�picerie M�tro',
#  'Other - Airport',
#  'Other - Stanislas School',
#  'Resto et �piceries',
#  'biod�me',
#  'A�roport Dorval',
#  'Promenade Fleury',
#  'Banks',
#  "Centre d'achat",
#  '�picerie',
#  'Park and Mall',
#  'Town pool',
#  'Restos-boutiques ',
#  'Italian church',
#  'Loblaws',
#  'All less than 10 minutes by car',
#  "bord de l'eau",
#  'Dogs park',
#  'Jarry Park',
#  'Shopping Mall',
#  'museum',
#  'McGill university',
#  'm�tro Charlevoix',
#  'train de banlieu � venir',
#  'Swim. pool of Cégep du V.M',
#  'grocery,pharmacy,clinics,bank,SAQ,hairsalon',
#  'Shopping center',
#  'near water front',
#  'church',
#  'Services and retail',
#  'a 5 minutes du centre-ville',
#  'Restaurants',
#  'Angrignon Mall',
#  'M�tro - Station LaSalle',
#  'SHOPING CENTER AND MOVIE THEATER',
#  'hospital',
#  'tous les services rue Mont-Royal',
#  'atwater Market and Lachine Canal',
#  'Golf',
#  'Casino & Ile-Ste-Helene',
#  'Park',
#  'ointe claire village and beaconsfield yacht club',
#  'SAQ',
#  'Pharmacies',
#  'CEGEP',
#  '.picerie distance de marche',
#  'Fairview shopping Mall',
#  'Restos',
#  'Public market',
#  'Verdun Auditorium',
#  'Parc Nature',
#  'wather side',
#  'm�tro Square Victoria',
#  '�picerie Loblaws Angus',
#  'Bientot train de banlieu',
#  'Jean-Talon Market',
#  'boutiques ',
#  "Galerie d'anjou et centre commercial",
#  'To everything! ',
#  'Well situated... near all services',
#  'Cross-country skiing',
#  'shopping centers',
#  'Notre-Dame Basilique',
#  '3min from Verdun metro',
#  'Cegep',
#  'Shops Angus.',
#  'restaurants',
#  '�cole de Musique',
#  'Fleuve et Quai du Vieux-Montr�al',
#  'Supermarch�',
#  'Autobus 104,105,138,356,420',
#  'courts',
#  'cegep',
#  'parc Maisonneuve',
#  'Parc Bellerive',
#  'Centre Commercial,Clinique,Pharmacie',
#  'mountain.',
#  'Atwater Market',
#  'March� Adonis',
#  'Future Beach',
#  'Centre J-C Mal�part',
#  'Shop angus + �picerie 5 minutes',
#  'airport',
#  'Centre Commerciaux',
#  'Carrefour Angrignon',
#  'Shopping centers',
#  'Arena',
#  'Benny Sports Centre',
#  'parc',
#  'Mcgill university',
#  'shops',
#  'Yacht club',
#  'Rue Masson',
#  'Park & Mall',
#  'etc...',
#  'Aquadome',
#  'Resto',
#  'Bars',
#  'canoe and sailing clubs',
#  'pharmacie.',
#  ',Bibliotheque',
#  'Adonis supermarket and Sami Fruit',
#  'GYM',
#  'Walk score 100',
#  'pharmacie et SAQ',
#  'drugstore',
#  'Commuter train,marina,tennis',
#  'Shopping mall',
#  'tous les commerces de Mont-Royal',
#  'Pr�s Uqam,Radio Canada',
#  'Jean-Drapeau Park',
#  'Caisse',
#  'Centre Claude-Robillard',
#  'M�tro de Verdun !!!!!!',
#  'arena',
#  'Rivi�re Des Prairies',
#  'Vieux Montr�al',
#  'etc.',
#  'Public transport',
#  'ar�na',
#  'cote vertu shoping center ',
#  'Place Ville Marie',
#  'commerces',
#  'skating ring',
#  'Biod�me',
#  'centre aquatique',
#  'fleuve St-Laurent.',
#  'Parc Maisonneuve',
#  'Waterfront',
#  'Epiecerie',
#  '�cole des Adultes.',
#  'commercial street',
#  'Jardin botanique,stade,Shop Angus',
#  'Other - A Few Steps From Monkland Ave.',
#  'March� Atwater ',
#  'Plusieurs services',
#  'R�no-D�p�t et autres.',
#  'highway 13 /15',
#  'Other',
#  'Promenade Ontario',
#  'Métro Jarry',
#  'synagogue',
#  'shopping center',
#  'Library',
#  'caf�',
#  'Centre Claude Robillard',
#  'Near downton and Mc Gill University',
#  'Laurier',
#  'Montr�al Old Port',
#  'boutiques',
#  'trin station',
#  'Carrefour Angrinion',
#  'Airport',
#  'Shops',
#  'Canal Lachine / March� Atwater / Nordelec',
#  'restos-boutiques -bar',
#  'Club Acuatique',
#  'Downtown',
#  'Mont-Royal',
#  'YMCA',
#  'Stations de m�tro Langelier et Cadillac',
#  'Festivals',
#  'Bicycle path',
#  'Alpine skiing',
#  'Marche Atwater',
#  'Costco',
#  'CLSC',
#  'Plusieurs commerces',
#  'Canal',
#  'parc maisonneuve',
#  'In the heart of MileEnd',
#  'Highway',
#  "Galerie d'anjou",
#  'futur train de banlieue',
#  'centres commerciaux et restos',
#  'restos ',
#  'Griffintown',
#  'Centre sportif complet',
#  'Old Port',
#  'Stanislas College',
#  'steps from all services',
#  'pharmacies',
#  'DORVAL AIRPORT']

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer(sparse_output=True)
data = data.join(pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(data.pop('Proximity')),
                index=data.index,
                columns=mlb.classes_))

# %%
data.drop(['', '+'], axis = 1, inplace=True)

# %%
#saving data into csv
data.to_csv('extra_data_modified.csv', encoding='utf-8', index=False)
