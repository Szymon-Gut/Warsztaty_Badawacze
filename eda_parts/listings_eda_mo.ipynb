# %% [markdown]
# # listings.csv - data from centris.ca

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listings = pd.read_csv("listings.csv")

# %% [markdown]
# ## Overview

# %%
listings.head()
# Out:
#                                         __type  MlsNumber CategoryCode  \
# 0  Centris.CentrisCA.Domain.Views.PropertyView    9027411          COP
# 1  Centris.CentrisCA.Domain.Views.PropertyView    9030205          PPR
# 2  Centris.CentrisCA.Domain.Views.PropertyView    9041238          PCI
# 3  Centris.CentrisCA.Domain.Views.PropertyView    9048590          PPR
# 4  Centris.CentrisCA.Domain.Views.PropertyView    9066959          COP
#
#          Lat        Lng                              Address  \
# 0  45.556508 -73.633198    8708, Av. André-Grasset, apt. 202
# 1  45.542062 -73.696868           12064 - 12066, Rue Valmont
# 2  45.573887 -73.649079           2326 - 2328, Rue Fleury E.
# 3  45.571040 -73.643413            2283 - 2287, Rue Sauvé E.
# 4  45.533876 -73.672649  2110, Rue Caroline-Béique, apt. 804
#
#                                City          Quartier  \
# 0  Ahuntsic-Cartierville (Montréal)  Ahuntsic Central
# 1  Ahuntsic-Cartierville (Montréal)  Nouveau Bordeaux
# 2  Ahuntsic-Cartierville (Montréal)     Ahuntsic East
# 3  Ahuntsic-Cartierville (Montréal)     Ahuntsic East
# 4  Ahuntsic-Cartierville (Montréal)  Nouveau Bordeaux
#
#                           ShortCity PostalCode  ...  IsFavoriteDisplayed  \
# 0  Ahuntsic-Cartierville (Montréal)    H2M 2L4  ...                 True
# 1  Ahuntsic-Cartierville (Montréal)    H3M 2V5  ...                 True
# 2  Ahuntsic-Cartierville (Montréal)    H2B 1K9  ...                 True
# 3  Ahuntsic-Cartierville (Montréal)    H2B 1B4  ...                 True
# 4  Ahuntsic-Cartierville (Montréal)    H4N 3K2  ...                 True
#
#   IsRemovedDisplayed IsNewPrice  IsNew  \
# 0               True      False  False
# 1               True      False  False
# 2               True      False  False
# 3               True      False  False
# 4               True      False  False
#
#                                            PageTitle IsEmptyView Langue  \
# 0  Condos for sale in Ahuntsic-Cartierville (Mont...       False    NaN
# 1  Duplexes for sale in Ahuntsic-Cartierville (Mo...       False    NaN
# 2  Commercial building for sale in Ahuntsic-Carti...       False    NaN
# 3  Triplexes for sale in Ahuntsic-Cartierville (M...       False    NaN
# 4  Condos for sale in Ahuntsic-Cartierville (Mont...       False    NaN
#
#                                 GoogleMapAddressLink IsMissingView  \
# 0  https://maps.google.ca/maps?z=17&q=45.556508,-...         False
# 1  https://maps.google.ca/maps?z=17&q=45.542062,-...         False
# 2  https://maps.google.ca/maps?z=17&q=45.57388725...         False
# 3  https://maps.google.ca/maps?z=17&q=45.57104035...         False
# 4  https://maps.google.ca/maps?z=17&q=45.533876,-...         False
#
#   IsInFavorite
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 65 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14667 entries, 0 to 14666
# Data columns (total 65 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   __type                14667 non-null  object
#  1   MlsNumber             14667 non-null  int64
#  2   CategoryCode          14667 non-null  object
#  3   Lat                   14667 non-null  float64
#  4   Lng                   14667 non-null  float64
#  5   Address               14667 non-null  object
#  6   City                  14667 non-null  object
#  7   Quartier              11488 non-null  object
#  8   ShortCity             14667 non-null  object
#  9   PostalCode            14667 non-null  object
#  10  ShortDescription      0 non-null      float64
#  11  LongDescription       12922 non-null  object
#  12  PhotoText             14667 non-null  object
#  13  BuyPrice              14667 non-null  object
#  14  BuyPriceDesc          2811 non-null   object
#  15  LocationPrice         259 non-null    object
#  16  LocationPriceDesc     259 non-null    object
#  17  Category              14667 non-null  object
#  18  Construction          12237 non-null  object
#  19  OpenHouse             875 non-null    object
#  20  GenreCode             14667 non-null  object
#  21  CatgCode              14667 non-null  object
#  22  Utilisation           3306 non-null   object
#  23  RevenuEffectif        14667 non-null  int64
#  24  RevenuBrutPotentiel   14667 non-null  int64
#  25  WalkScore             14667 non-null  int64
#  26  SuperficieTerrain     14667 non-null  int64
#  27  NbPieces              14667 non-null  int64
#  28  NbChambres            14667 non-null  int64
#  29  NbSallesEaux          14667 non-null  int64
#  30  NbSallesBains         14667 non-null  int64
#  31  NbFoyerPoele          14667 non-null  int64
#  32  NbEquipements         14667 non-null  int64
#  33  NbGarages             14667 non-null  int64
#  34  NbStationnements      14667 non-null  int64
#  35  NbPiscines            14667 non-null  int64
#  36  NbBordEaux            14667 non-null  int64
#  37  NbAnimals             14667 non-null  int64
#  38  NbCultures            14667 non-null  int64
#  39  DiffusionWebUrl       14667 non-null  object
#  40  PhotoUrl              14667 non-null  object
#  41  PhotoPrintingUrl      14667 non-null  object
#  42  FinancialToolUrl      14667 non-null  object
#  43  PasserelleUrl         13926 non-null  object
#  44  CommunityUrl          14667 non-null  object
#  45  GoogleStreetViewUrl   14667 non-null  object
#  46  WalkScoreUrl          14667 non-null  object
#  47  VisiteVirtuelleUrl    2601 non-null   object
#  48  ShareThisUrl          14667 non-null  object
#  49  SummaryUrl            14667 non-null  object
#  50  PrintingPageUrl       14667 non-null  object
#  51  IsFavorite            14667 non-null  bool
#  52  IsRemoved             14667 non-null  bool
#  53  IsSubject             14667 non-null  bool
#  54  IsStrictQueryMatch    14667 non-null  bool
#  55  IsFavoriteDisplayed   14667 non-null  bool
#  56  IsRemovedDisplayed    14667 non-null  bool
#  57  IsNewPrice            14667 non-null  bool
#  58  IsNew                 14667 non-null  bool
#  59  PageTitle             14667 non-null  object
#  60  IsEmptyView           14667 non-null  bool
#  61  Langue                0 non-null      float64
#  62  GoogleMapAddressLink  14667 non-null  object
#  63  IsMissingView         14667 non-null  bool
#  64  IsInFavorite          14667 non-null  bool
# dtypes: bool(11), float64(4), int64(17), object(33)
# memory usage: 6.2+ MB

# %% [markdown]
# ## First transformations

# %% [markdown]
# ### Remove columns without non-null values

# %%
just_nulls = ["ShortDescription", "Langue"]
df = listings.drop(just_nulls, axis=1)

# %% [markdown]
# ### Dropping columns containing URLs

# %%
url_cols = [colname for colname in df.columns if colname.endswith("Url")]
url_cols.append("GoogleMapAddressLink")
len(url_cols)
# Out:
# 13

# %%
df = df.drop(url_cols, axis=1)

# %% [markdown]
# ### Converting prices to numerical values

# %%
df["BuyPrice"].dropna()
# Out:
# 0          $187,500
# 1          $574,900
# 2          $475,000
# 3          $545,000
# 4          $200,000
#             ...
# 14662      $760,000
# 14663    $1,295,000
# 14664    $1,450,000
# 14665    $2,268,000
# 14666    $1,950,000
# Name: BuyPrice, Length: 14667, dtype: object

# %%
df["LocationPrice"].dropna()
# Out:
# 45       $2,500
# 105      $1,100
# 118      $1,450
# 493      $1,200
# 531        $950
#           ...
# 14569    $2,350
# 14577    $6,500
# 14614    $5,000
# 14617    $5,900
# 14642    $3,250
# Name: LocationPrice, Length: 259, dtype: object

# %%
def convert_price_to_num(price: str) -> float:
    """
    Example input: "$1,234,567.89"
    Example output: 1234567.99
    """
    # handle nan values
    if price != price:
        return price
    # remove the dollar sign
    price = price[1:]
    # remove commas
    price = price.replace(",", "")

    return float(price)

# %%
df[["BuyPrice", "LocationPrice"]] = df[["BuyPrice", "LocationPrice"]].applymap(convert_price_to_num)

# %%
df[["BuyPrice", "LocationPrice"]].head()
# Out:
#    BuyPrice  LocationPrice
# 0  187500.0            NaN
# 1  574900.0            NaN
# 2  475000.0            NaN
# 3  545000.0            NaN
# 4  200000.0            NaN

# %%
df[["BuyPrice", "LocationPrice"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14667 entries, 0 to 14666
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BuyPrice       14667 non-null  float64
#  1   LocationPrice  259 non-null    float64
# dtypes: float64(2)
# memory usage: 229.3 KB

# %% [markdown]
# ### BuyPriceDesc & LocationPriceDesc

# %%
df['BuyPriceDesc'].value_counts()
# Out:
#  +GST/QST                 2791
#  /square foot +GST/QST      17
#  /square foot                3
# Name: BuyPriceDesc, dtype: int64

# %%
df['LocationPriceDesc'].value_counts()
# Out:
#  /month                         244
#  /month +GST/QST                 11
#  /year /square foot +GST/QST      2
#  /year +GST/QST                   1
#  /year                            1
# Name: LocationPriceDesc, dtype: int64

# %% [markdown]
# #### Almost all listings on centris.ca in Montreal have their area specified in square foot, so this information here is probably redundant

# %%
df.loc[df['BuyPriceDesc'] == ' /square foot', 'BuyPriceDesc'] = np.nan
df.loc[df['BuyPriceDesc'] == ' /square foot +GST/QST', 'BuyPriceDesc'] = " +GST/QST"
df.loc[df['LocationPriceDesc'] == ' /year /square foot +GST/QST', 'LocationPriceDesc'] = ' /year +GST/QST'

# %% [markdown]
# #### Changing all prices in LocationPrice to be /month

# %%
prices_per_year = (df['LocationPriceDesc'] == ' /year') | (df['LocationPriceDesc'] == ' /year +GST/QST')
df.loc[prices_per_year, 'LocationPrice'] = df.loc[prices_per_year, 'LocationPrice'] / 12

# %%
df.loc[df['LocationPriceDesc'] == ' /year', 'LocationPriceDesc'] = np.nan
df.loc[df['LocationPriceDesc'] == ' /year +GST/QST', 'LocationPriceDesc'] = ' +GST/QST'
df.loc[df['LocationPriceDesc'] == ' /month', 'LocationPriceDesc'] = np.nan
df.loc[df['LocationPriceDesc'] == ' /month +GST/QST', 'LocationPriceDesc'] = ' +GST/QST'

# %%
df['BuyPriceDesc'].value_counts()
# Out:
#  +GST/QST    2808
# Name: BuyPriceDesc, dtype: int64

# %%
df['LocationPriceDesc'].value_counts()
# Out:
#  +GST/QST    14
# Name: LocationPriceDesc, dtype: int64

# %% [markdown]
# #### Change BuyPriceDesc & LocationPriceDesc to logical variables

# %%
df[['BuyPriceDesc', 'LocationPriceDesc']] = df[['BuyPriceDesc', 'LocationPriceDesc']].applymap(lambda x: x == ' +GST/QST')
df = df.rename(columns={'BuyPriceDesc': 'BuyPriceGSTQST', 'LocationPriceDesc': 'LocationPriceGSTQST'})

# %%
df['BuyPriceGSTQST'].value_counts()
# Out:
# False    11859
# True      2808
# Name: BuyPriceGSTQST, dtype: int64

# %%
df['LocationPriceGSTQST'].value_counts()
# Out:
# False    14653
# True        14
# Name: LocationPriceGSTQST, dtype: int64

# %% [markdown]
# ## Inspecting columns that have missing data

# %% [markdown]
# #### Quartier (78% non-null)

# %%
df["Quartier"].value_counts()
# Out:
# Central                           1244
# Central West                       831
# Le Plateau-Mont-Royal              735
# Mercier                            591
# Rivière-des-Prairies               504
# Hochelaga-Maisonneuve              499
# Île-des-Soeurs                     442
# Rosemont                           431
# Saint-Henri/Petite Bourgogne       428
# Pointe-aux-Trembles                416
# Côte-des-Neiges                    400
# Villeray                           342
# East                               336
# Notre-Dame-de-Grâce                336
# Saint-Michel                       302
# La Petite-Patrie                   299
# Old Montréal                       251
# Verdun                             235
# Saint-Paul/Émard                   228
# Nouveau Bordeaux                   192
# Pierrefonds/Central East           176
# L'Île-Bizard                       163
# Pointe-Saint-Charles               160
# West                               146
# Ahuntsic West                      143
# Mile-End                           136
# Ahuntsic Central                   131
# Pierrefonds/Central West           121
# South East                         119
# Pierrefonds/West                   103
# South West                         101
# Cartierville                        96
# Central East                        86
# Parc-Extension                      85
# Ahuntsic East                       79
# Pierrefonds/East                    70
# Bois de Saraguay                    55
# North                               55
# Sherwood (North West)               51
# Sainte-Geneviève                    49
# Saint-Pierre                        49
# Roxboro                             41
# North West                          37
# Central South                       35
# New Rosemont                        34
# Beaurepaire (South West)            29
# North East                          26
# Timberlea                           22
# South                               19
# Beacon Hill (North East)            15
# Forest Gardens (Central North)      14
# Name: Quartier, dtype: int64

# %% [markdown]
# #### LongDescription (88% non-null)

# %%
df["LongDescription"].head()
# Out:
# 0    PRIX POUR VENTE RAPIDE. Superbe condo ensoleil...
# 1    Duplex à vendre à Ahuntsic près de la rivière,...
# 2    rare sur le marché! ideal pour dentiste ou med...
# 3    Excellent opportunity for builder/ contractor....
# 4    Beautiful condo built in 2011 still under guar...
# Name: LongDescription, dtype: object

# %% [markdown]
# #### Construction (83% non-null)

# %%
df["Construction"].value_counts()
# Out:
# Construction 2013    474
# Construction 2012    472
# Construction 2011    357
# Construction 2014    328
# Construction 1910    324
#                     ...
# Construction 1868      1
# Construction 1815      1
# Construction 1823      1
# Construction 1828      1
# Construction 1830      1
# Name: Construction, Length: 160, dtype: int64

# %% [markdown]
# ##### Transform it to a numerical column

# %%
df[["Construction"]] = df[["Construction"]].applymap(lambda x: np.nan if x != x else int(x[13:]))

# %%
df["Construction"].value_counts()
# Out:
# 2013.0    474
# 2012.0    472
# 2011.0    357
# 2014.0    328
# 1910.0    324
#          ...
# 1864.0      1
# 1869.0      1
# 1894.0      1
# 1867.0      1
# 1820.0      1
# Name: Construction, Length: 160, dtype: int64

# %% [markdown]
# #### OpenHouse (6% non-null)

# %% [markdown]
# "An open house is a scheduled period of time in which a home is available for viewing by potential buyers. Open houses can attract interested buyers and lead to an offer or alert the realtor to issues with the space that might be pointed out."

# %%
df["OpenHouse"].value_counts()  # moze przerobic na wartosc logiczna?
# Out:
# Open house: 11/09/2014, 2 PM - 4 PM           632
# Open house: 11/09/2014, 1 PM - 5 PM            73
# Open house: 11/09/2014, 1 PM - 4 PM            65
# Open house: 11/16/2014, 2 PM - 4 PM            26
# Open house: 11/09/2014, 3 PM - 4 PM            19
# Open house: 11/09/2014, 12 PM - 5 PM           14
# Open house: 11/09/2014, 1:30 PM - 2:30 PM      13
# Open house: 11/09/2014, 11 AM - 4 PM           10
# Open house: 11/09/2014, 1 PM - 3 PM             3
# Open house: 11/09/2014, 2 PM - 3 PM             2
# Open house: 11/09/2014, 2 PM - 5 PM             2
# Open house: 11/16/2014, 1 PM - 4 PM             2
# Open house: 11/09/2014, 12:30 PM - 1:30 PM      1
# Open house: 11/16/2014, 12 PM - 1 PM            1
# Open house: 11/09/2014, 2 PM - 4:30 PM          1
# Open house: 11/09/2014, 1:30 PM - 4 PM          1
# Open house: 11/09/2014, 4:30 PM - 5:30 PM       1
# Open house: 11/09/2014, 2:30 PM - 4 PM          1
# Open house: 11/22/2014, 2 PM - 4 PM             1
# Open house: 11/30/2014, 2 PM - 4 PM             1
# Open house: 11/09/2014, 1:30 PM - 3:30 PM       1
# Open house: 11/23/2014, 2 PM - 4 PM             1
# Open house: 11/09/2014, 10 AM - 12 PM           1
# Open house: 11/09/2014, 1 PM - 2 PM             1
# Open house: 11/09/2014, 1 PM - 2:30 PM          1
# Open house: 11/09/2014, 3:30 PM - 4:30 PM       1
# Name: OpenHouse, dtype: int64

# %% [markdown]
# #### Utilisation (23% non-null)

# %%
df["Utilisation"].value_counts()
# Out:
# Residential only                     2299
# Commercial only                       392
# Residential and commercial            255
# Commercial and office space           139
# Commercial and residential            124
# Commercial and industrial              22
# Industrial and offices                 19
# Industrial only                        15
# Offices only                           14
# Other                                  14
# Multi-family dwelling                   5
# Commercial or industrial (income)       4
# Retirement home                         4
# Name: Utilisation, dtype: int64

# %% [markdown]
# ## Inscpecting some columns with values of an object type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14667 entries, 0 to 14666
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   __type               14667 non-null  object
#  1   MlsNumber            14667 non-null  int64
#  2   CategoryCode         14667 non-null  object
#  3   Lat                  14667 non-null  float64
#  4   Lng                  14667 non-null  float64
#  5   Address              14667 non-null  object
#  6   City                 14667 non-null  object
#  7   Quartier             11488 non-null  object
#  8   ShortCity            14667 non-null  object
#  9   PostalCode           14667 non-null  object
#  10  LongDescription      12922 non-null  object
#  11  PhotoText            14667 non-null  object
#  12  BuyPrice             14667 non-null  float64
#  13  BuyPriceGSTQST       14667 non-null  bool
#  14  LocationPrice        259 non-null    float64
#  15  LocationPriceGSTQST  14667 non-null  bool
#  16  Category             14667 non-null  object
#  17  Construction         12237 non-null  float64
#  18  OpenHouse            875 non-null    object
#  19  GenreCode            14667 non-null  object
#  20  CatgCode             14667 non-null  object
#  21  Utilisation          3306 non-null   object
#  22  RevenuEffectif       14667 non-null  int64
#  23  RevenuBrutPotentiel  14667 non-null  int64
#  24  WalkScore            14667 non-null  int64
#  25  SuperficieTerrain    14667 non-null  int64
#  26  NbPieces             14667 non-null  int64
#  27  NbChambres           14667 non-null  int64
#  28  NbSallesEaux         14667 non-null  int64
#  29  NbSallesBains        14667 non-null  int64
#  30  NbFoyerPoele         14667 non-null  int64
#  31  NbEquipements        14667 non-null  int64
#  32  NbGarages            14667 non-null  int64
#  33  NbStationnements     14667 non-null  int64
#  34  NbPiscines           14667 non-null  int64
#  35  NbBordEaux           14667 non-null  int64
#  36  NbAnimals            14667 non-null  int64
#  37  NbCultures           14667 non-null  int64
#  38  IsFavorite           14667 non-null  bool
#  39  IsRemoved            14667 non-null  bool
#  40  IsSubject            14667 non-null  bool
#  41  IsStrictQueryMatch   14667 non-null  bool
#  42  IsFavoriteDisplayed  14667 non-null  bool
#  43  IsRemovedDisplayed   14667 non-null  bool
#  44  IsNewPrice           14667 non-null  bool
#  45  IsNew                14667 non-null  bool
#  46  PageTitle            14667 non-null  object
#  47  IsEmptyView          14667 non-null  bool
#  48  IsMissingView        14667 non-null  bool
#  49  IsInFavorite         14667 non-null  bool
# dtypes: bool(13), float64(5), int64(17), object(15)
# memory usage: 4.3+ MB

# %% [markdown]
# ### __type

# %%
df['__type'].value_counts()
# Out:
# Centris.CentrisCA.Domain.Views.PropertyView    14667
# Name: __type, dtype: int64

# %% [markdown]
# Can be dropped

# %%
df = df.drop(['__type'], axis=1)

# %% [markdown]
# ### Category

# %%
df['Category'].value_counts()
# Out:
# Condo/Loft, Apartment, Detached                3338
# Condo/Loft, Apartment, Attached                2255
# Condo/Loft, Apartment, Semi-detached           1385
# Single Family, Two or more storey, Detached    1344
# Single Family, Bungalow, Detached               647
#                                                ...
# Lot, 5,750 sqft                                   1
# Revenue Property, Semi-detached, 14 Plex          1
# Revenue Property, Attached, 26 UNITS              1
# Lot, 3,832 sqft                                   1
# Lot, 11,781 sqft                                  1
# Name: Category, Length: 408, dtype: int64

# %% [markdown]
# ### CategoryCode & CatgCode

# %%
df['CategoryCode'].value_counts()
# Out:
# COP    7698
# UNI    3522
# PPR    2587
# PCI     719
# TER     140
# FER       1
# Name: CategoryCode, dtype: int64

# %%
df['CatgCode'].value_counts()
# Out:
# COP    7698
# UNI    3522
# PPR    2587
# PCI     719
# TER     140
# FER       1
# Name: CatgCode, dtype: int64

# %% [markdown]
# #### CategoryCode and CatgCode are identical - one of them can be dropped

# %%
np.sum(df['CategoryCode'] != df['CatgCode'])
# Out:
# 0

# %%
df = df.drop(['CatgCode'], axis=1)

# %% [markdown]
# ### City & ShortCity

# %%
df['City'].value_counts()
# Out:
# Ville-Marie (Montréal)                                 2087
# Mercier/Hochelaga-Maisonneuve (Montréal)               1124
# Rivière-des-Prairies/Pointe-aux-Trembles (Montréal)     920
# Le Plateau-Mont-Royal (Montréal)                        871
# Le Sud-Ouest (Montréal)                                 816
# Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)          736
# Rosemont/La Petite-Patrie (Montréal)                    730
# Villeray/Saint-Michel/Parc-Extension (Montréal)         729
# Saint-Laurent (Montréal)                                704
# Ahuntsic-Cartierville (Montréal)                        696
# Verdun/Île-des-Soeurs (Montréal)                        677
# Pierrefonds-Roxboro (Montréal)                          511
# LaSalle (Montréal)                                      470
# Montréal-Nord (Montréal)                                433
# Lachine (Montréal)                                      361
# Dollard-Des Ormeaux                                     333
# Côte-Saint-Luc                                          278
# Anjou (Montréal)                                        256
# Saint-Léonard (Montréal)                                248
# Westmount                                               236
# Mont-Royal                                              212
# L'Île-Bizard/Sainte-Geneviève (Montréal)                212
# Pointe-Claire                                           177
# Outremont (Montréal)                                    158
# Beaconsfield                                            156
# Dorval                                                  129
# Kirkland                                                124
# Hampstead                                                64
# Baie-d'Urfé                                              64
# Montréal-Est                                             57
# Sainte-Anne-de-Bellevue                                  35
# Montréal-Ouest                                           35
# Senneville                                               28
# Name: City, dtype: int64

# %%
df['ShortCity'].value_counts()
# Out:
# Ville-Marie (Montréal)                      2087
# Mercier/Hochelaga-Maisonneuve (Montréal)    1124
# Rivière-des-Prairies/Pointe-aux-Tre ...      920
# Le Plateau-Mont-Royal (Montréal)             871
# Le Sud-Ouest (Montréal)                      816
# Côte-des-Neiges/Notre-Dame-de-Grâce ...      736
# Rosemont/La Petite-Patrie (Montréal)         730
# Villeray/Saint-Michel/Parc-Extensio ...      729
# Saint-Laurent (Montréal)                     704
# Ahuntsic-Cartierville (Montréal)             696
# Verdun/Île-des-Soeurs (Montréal)             677
# Pierrefonds-Roxboro (Montréal)               511
# LaSalle (Montréal)                           470
# Montréal-Nord (Montréal)                     433
# Lachine (Montréal)                           361
# Dollard-Des Ormeaux                          333
# Côte-Saint-Luc                               278
# Anjou (Montréal)                             256
# Saint-Léonard (Montréal)                     248
# Westmount                                    236
# L'Île-Bizard/Sainte-Geneviève (Montréal)     212
# Mont-Royal                                   212
# Pointe-Claire                                177
# Outremont (Montréal)                         158
# Beaconsfield                                 156
# Dorval                                       129
# Kirkland                                     124
# Baie-d'Urfé                                   64
# Hampstead                                     64
# Montréal-Est                                  57
# Sainte-Anne-de-Bellevue                       35
# Montréal-Ouest                                35
# Senneville                                    28
# Name: ShortCity, dtype: int64

# %% [markdown]
# #### City and ShortCity have very similar values

# %%
df.loc[df['City'] != df['ShortCity'], ['ShortCity', 'City']].sample(n=20)
# Out:
#                                      ShortCity  \
# 14024  Villeray/Saint-Michel/Parc-Extensio ...
# 14194  Villeray/Saint-Michel/Parc-Extensio ...
# 9109   Rivière-des-Prairies/Pointe-aux-Tre ...
# 1388   Côte-des-Neiges/Notre-Dame-de-Grâce ...
# 14324  Villeray/Saint-Michel/Parc-Extensio ...
# 14218  Villeray/Saint-Michel/Parc-Extensio ...
# 8492   Rivière-des-Prairies/Pointe-aux-Tre ...
# 14362  Villeray/Saint-Michel/Parc-Extensio ...
# 9088   Rivière-des-Prairies/Pointe-aux-Tre ...
# 13733  Villeray/Saint-Michel/Parc-Extensio ...
# 1846   Côte-des-Neiges/Notre-Dame-de-Grâce ...
# 14151  Villeray/Saint-Michel/Parc-Extensio ...
# 1206   Côte-des-Neiges/Notre-Dame-de-Grâce ...
# 8321   Rivière-des-Prairies/Pointe-aux-Tre ...
# 8704   Rivière-des-Prairies/Pointe-aux-Tre ...
# 14081  Villeray/Saint-Michel/Parc-Extensio ...
# 9001   Rivière-des-Prairies/Pointe-aux-Tre ...
# 1581   Côte-des-Neiges/Notre-Dame-de-Grâce ...
# 14091  Villeray/Saint-Michel/Parc-Extensio ...
# 1747   Côte-des-Neiges/Notre-Dame-de-Grâce ...
#
#                                                     City
# 14024    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 14194    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 9109   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 1388      Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)
# 14324    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 14218    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 8492   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 14362    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 9088   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 13733    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 1846      Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)
# 14151    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 1206      Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)
# 8321   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 8704   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 14081    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 9001   Rivière-des-Prairies/Pointe-aux-Trembles (Mont...
# 1581      Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)
# 14091    Villeray/Saint-Michel/Parc-Extension (Montréal)
# 1747      Côte-des-Neiges/Notre-Dame-de-Grâce (Montréal)

# %% [markdown]
# #### ShortCity can probably be dropped

# %%
df = df.drop(['ShortCity'], axis=1)

# %% [markdown]
# ### PhotoText & PageTitle

# %%
df[['PhotoText']]
# Out:
#                                                PhotoText
# 0      Condos for sale in Ahuntsic-Cartierville (Mont...
# 1      Duplexes for sale in Ahuntsic-Cartierville (Mo...
# 2      Commercial building for sale in Ahuntsic-Carti...
# 3      Triplexes for sale in Ahuntsic-Cartierville (M...
# 4      Condos for sale in Ahuntsic-Cartierville (Mont...
# ...                                                  ...
# 14662  Condos for sale in Westmount, Montréal (Island...
# 14663  Houses for sale in Westmount, Montréal (Island...
# 14664  Condos for sale in Westmount, Montréal (Island...
# 14665  Houses for sale in Westmount, Montréal (Island...
# 14666  Houses for sale in Westmount, Montréal (Island...
#
# [14667 rows x 1 columns]

# %%
df[['PageTitle']]
# Out:
#                                                PageTitle
# 0      Condos for sale in Ahuntsic-Cartierville (Mont...
# 1      Duplexes for sale in Ahuntsic-Cartierville (Mo...
# 2      Commercial building for sale in Ahuntsic-Carti...
# 3      Triplexes for sale in Ahuntsic-Cartierville (M...
# 4      Condos for sale in Ahuntsic-Cartierville (Mont...
# ...                                                  ...
# 14662  Condos for sale in Westmount, Montréal (Island...
# 14663  Houses for sale in Westmount, Montréal (Island...
# 14664  Condos for sale in Westmount, Montréal (Island...
# 14665  Houses for sale in Westmount, Montréal (Island...
# 14666  Houses for sale in Westmount, Montréal (Island...
#
# [14667 rows x 1 columns]

# %% [markdown]
# #### Same case as with CategoryCode & CatgCode

# %%
np.sum(df['PhotoText'] != df['PageTitle'])
# Out:
# 0

# %%
df = df.drop(['PhotoText'], axis=1)

# %% [markdown]
# ### GenreCode

# %%
df['GenreCode'].value_counts()
# Out:
# AP     7385
# ME     2362
# 2X     1190
# PP      797
# 3X      649
# VE      389
# AU      386
# MPM     325
# C       285
# 4X      236
# MA      185
# LS      128
# 5X      126
# TR      123
# I        45
# MEM      27
# TE       17
# MM       11
# FE        1
# Name: GenreCode, dtype: int64

# %% [markdown]
# ## Columns wtih boolean values

# %%
df['IsNewPrice'].value_counts()
# Out:
# False    14638
# True        29
# Name: IsNewPrice, dtype: int64

# %%
df['IsNew'].value_counts()
# Out:
# False    14621
# True        46
# Name: IsNew, dtype: int64

# %% [markdown]
# ### Other columns are reduntant:

# %%
df['IsFavorite'].value_counts()
# Out:
# False    14667
# Name: IsFavorite, dtype: int64

# %%
df['IsRemoved'].value_counts()
# Out:
# False    14667
# Name: IsRemoved, dtype: int64

# %%
df['IsSubject'].value_counts()
# Out:
# False    14667
# Name: IsSubject, dtype: int64

# %%
df['IsStrictQueryMatch'].value_counts()
# Out:
# False    14667
# Name: IsStrictQueryMatch, dtype: int64

# %%
df['IsFavoriteDisplayed'].value_counts()
# Out:
# True    14667
# Name: IsFavoriteDisplayed, dtype: int64

# %%
df['IsRemovedDisplayed'].value_counts()
# Out:
# True    14667
# Name: IsRemovedDisplayed, dtype: int64

# %%
df['IsEmptyView'].value_counts()
# Out:
# False    14667
# Name: IsEmptyView, dtype: int64

# %%
df['IsMissingView'].value_counts()
# Out:
# False    14667
# Name: IsMissingView, dtype: int64

# %%
df['IsInFavorite'].value_counts()
# Out:
# False    14667
# Name: IsInFavorite, dtype: int64

# %%
df = df.drop(['IsFavorite', 'IsRemoved', 'IsSubject', 
        'IsStrictQueryMatch', 'IsFavoriteDisplayed', 'IsRemovedDisplayed', 
        'IsEmptyView', 'IsMissingView', 'IsInFavorite'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14667 entries, 0 to 14666
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MlsNumber            14667 non-null  int64
#  1   CategoryCode         14667 non-null  object
#  2   Lat                  14667 non-null  float64
#  3   Lng                  14667 non-null  float64
#  4   Address              14667 non-null  object
#  5   City                 14667 non-null  object
#  6   Quartier             11488 non-null  object
#  7   PostalCode           14667 non-null  object
#  8   LongDescription      12922 non-null  object
#  9   BuyPrice             14667 non-null  float64
#  10  BuyPriceGSTQST       14667 non-null  bool
#  11  LocationPrice        259 non-null    float64
#  12  LocationPriceGSTQST  14667 non-null  bool
#  13  Category             14667 non-null  object
#  14  Construction         12237 non-null  float64
#  15  OpenHouse            875 non-null    object
#  16  GenreCode            14667 non-null  object
#  17  Utilisation          3306 non-null   object
#  18  RevenuEffectif       14667 non-null  int64
#  19  RevenuBrutPotentiel  14667 non-null  int64
#  20  WalkScore            14667 non-null  int64
#  21  SuperficieTerrain    14667 non-null  int64
#  22  NbPieces             14667 non-null  int64
#  23  NbChambres           14667 non-null  int64
#  24  NbSallesEaux         14667 non-null  int64
#  25  NbSallesBains        14667 non-null  int64
#  26  NbFoyerPoele         14667 non-null  int64
#  27  NbEquipements        14667 non-null  int64
#  28  NbGarages            14667 non-null  int64
#  29  NbStationnements     14667 non-null  int64
#  30  NbPiscines           14667 non-null  int64
#  31  NbBordEaux           14667 non-null  int64
#  32  NbAnimals            14667 non-null  int64
#  33  NbCultures           14667 non-null  int64
#  34  IsNewPrice           14667 non-null  bool
#  35  IsNew                14667 non-null  bool
#  36  PageTitle            14667 non-null  object
# dtypes: bool(4), float64(5), int64(17), object(11)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Numerical columns

# %%
df.select_dtypes(['int64', 'float64']).hist(figsize=(18, 15))
plt.show()

# %% [markdown]
# ### NbAnimals, NbEquipements, RevenuEffectif & SuperficieTerrain contain only zeros and therefore can be dropped

# %%
df['NbAnimals'].value_counts()
# Out:
# 0    14667
# Name: NbAnimals, dtype: int64

# %%
df['NbEquipements'].value_counts()
# Out:
# 0    14667
# Name: NbEquipements, dtype: int64

# %%
df['RevenuEffectif'].value_counts()
# Out:
# 0    14667
# Name: RevenuEffectif, dtype: int64

# %%
df['SuperficieTerrain'].value_counts()
# Out:
# 0    14667
# Name: SuperficieTerrain, dtype: int64

# %%
df = df.drop(['NbAnimals', 'NbEquipements', 'RevenuEffectif', 'SuperficieTerrain'], axis=1)

# %% [markdown]
# ### NbCultures contains almost only zeros - there is one exception:

# %%
df['NbCultures'].value_counts()
# Out:
# 0    14666
# 1        1
# Name: NbCultures, dtype: int64

# %%
df[df['NbCultures'] == 1]
# Out:
#        MlsNumber CategoryCode        Lat        Lng           Address  \
# 10910    8683066          FER  45.441254 -73.950284  39, Av. Phillips
#
#              City Quartier PostalCode  \
# 10910  Senneville      NaN    H9X 3X5
#
#                                          LongDescription   BuyPrice  ...  \
# 10910  "URBAN CERTIFIED ORGANIC FARM" One of a kind o...  4300000.0  ...
#
#        NbSallesBains  NbFoyerPoele  NbGarages NbStationnements  NbPiscines  \
# 10910              2             1          4                2           0
#
#       NbBordEaux NbCultures IsNewPrice  IsNew  \
# 10910          0          1      False  False
#
#                                                PageTitle
# 10910  Farms for sale in Senneville, Montréal (Island...
#
# [1 rows x 33 columns]

# %% [markdown]
# ### Correlation matrix

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.select_dtypes(['int64', 'float64']).corr(), annot=True, cmap="BrBG")
plt.show()
